# %%
import pandas as pd
# Create data for CSV format
income_statement = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q1 2020 (in millions)": [41159, 18521, 22638, 13537, 9101, 434, 9535, 2722, 6813, 9.87]
}

balance_sheet = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q1 2020 (in millions)": [18467, 101181, 26602, 1065, 4815, 152130, 38964, 21173, 3731, 20722, 84590, 236720,
                              4928, 5459, 11292, 2152, 4998, 28829, 12758, 1237, 8365, 51189, 676, 36381, 156065, -1591,
                              191531, 236720]
}

cash_flow_statement = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q1 2020 (in millions)": [6813, 3255, 3250, 290, 1515, 35, -1200, -300, 13658, -5364, 85, -21528, 19356, -450,
                              -7901, 506, -8500, 2000, -1000, -6994, -1237, 19704, 18467]
}

# Convert to DataFrames
income_statement_df = pd.DataFrame(income_statement)
balance_sheet_df = pd.DataFrame(balance_sheet)
cash_flow_statement_df = pd.DataFrame(cash_flow_statement)

# Save to CSV
income_statement_df.to_csv('Alphabet_Q1_2020_Income_Statement.csv', index=False)
balance_sheet_df.to_csv('Alphabet_Q1_2020_Balance_Sheet.csv', index=False)
cash_flow_statement_df.to_csv('Alphabet_Q1_2020_Cash_Flow_Statement.csv', index=False)

# %%
# Q2 2020 Data Preparation

income_statement_q2 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q2 2020 (in millions)": [38297, 17335, 20962, 13932, 7030, 858, 7888, 1859, 6029, 8.92]
}

balance_sheet_q2 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q2 2020 (in millions)": [19488, 102278, 25119, 1098, 4639, 152622, 39109, 21229, 3695, 21034, 85067, 237689,
                              5049, 5561, 11560, 2184, 5028, 29382, 13003, 1287, 8487, 52159, 682, 36476, 156860, -1488,
                              192530, 237689]
}

cash_flow_statement_q2 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q2 2020 (in millions)": [6029, 3296, 3250, 286, 1483, 37, -1125, -292, 13964, -5491, 85, -21951, 19562, -460,
                              -8255, 511, -8600, 2000, -1000, -7089, -1380, 19488, 18108]
}

# Convert to DataFrames
income_statement_q2_df = pd.DataFrame(income_statement_q2)
balance_sheet_q2_df = pd.DataFrame(balance_sheet_q2)
cash_flow_statement_q2_df = pd.DataFrame(cash_flow_statement_q2)

# Save to CSV
income_statement_q2_df.to_csv('Alphabet_Q2_2020_Income_Statement.csv', index=False)
balance_sheet_q2_df.to_csv('Alphabet_Q2_2020_Balance_Sheet.csv', index=False)
cash_flow_statement_q2_df.to_csv('Alphabet_Q2_2020_Cash_Flow_Statement.csv', index=False)

# %%
# Q3 2020 Data Preparation

income_statement_q3 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q3 2020 (in millions)": [46173, 18633, 27540, 14229, 13311, 984, 14295, 3074, 11221, 16.40]
}

balance_sheet_q3 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q3 2020 (in millions)": [20520, 104732, 26941, 1116, 4897, 158206, 39322, 21377, 3653, 21456, 85808, 244014,
                              5112, 5607, 11738, 2207, 5074, 29738, 13247, 1337, 8637, 52959, 685, 36562, 158032, -1428,
                              193851, 244014]
}

cash_flow_statement_q3 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q3 2020 (in millions)": [11221, 3401, 3250, 284, 1478, 31, -1123, -295, 18247, -5504, 85, -22073, 20174, -468,
                              -7786, 517, -8750, 2000, -1000, -7233, 3228, 17292, 20520]
}

# Convert to DataFrames
income_statement_q3_df = pd.DataFrame(income_statement_q3)
balance_sheet_q3_df = pd.DataFrame(balance_sheet_q3)
cash_flow_statement_q3_df = pd.DataFrame(cash_flow_statement_q3)

# Save to CSV
income_statement_q3_df.to_csv('Alphabet_Q3_2020_Income_Statement.csv', index=False)
balance_sheet_q3_df.to_csv('Alphabet_Q3_2020_Balance_Sheet.csv', index=False)
cash_flow_statement_q3_df.to_csv('Alphabet_Q3_2020_Cash_Flow_Statement.csv', index=False)

# %%
# Q4 2020 Data Preparation

income_statement_q4 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q4 2020 (in millions)": [56898, 26217, 30681, 15061, 15620, 955, 16575, 3748, 12827, 18.58]
}

balance_sheet_q4 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q4 2020 (in millions)": [21884, 108299, 27418, 1140, 5023, 163764, 40159, 21493, 3729, 21885, 87266, 251030,
                              5303, 5694, 12016, 2250, 5094, 30357, 13529, 1409, 8834, 54129, 689, 36734, 158870, -1392,
                              194901, 251030]
}

cash_flow_statement_q4 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q4 2020 (in millions)": [12827, 3500, 3300, 300, 1500, 40, -1200, -400, 19867, -5700, 100, -23000, 21000, -500,
                              -8100, 520, -9000, 2000, -1000, -7480, 4387, 17897, 22284]
}

# Convert to DataFrames
income_statement_q4_df = pd.DataFrame(income_statement_q4)
balance_sheet_q4_df = pd.DataFrame(balance_sheet_q4)
cash_flow_statement_q4_df = pd.DataFrame(cash_flow_statement_q4)

# Save to CSV
income_statement_q4_df.to_csv('Alphabet_Q4_2020_Income_Statement.csv', index=False)
balance_sheet_q4_df.to_csv('Alphabet_Q4_2020_Balance_Sheet.csv', index=False)
cash_flow_statement_q4_df.to_csv('Alphabet_Q4_2020_Cash_Flow_Statement.csv', index=False)

# %%
# Prepare the data for Q1 to Q4 of 2021

# Example data for Q1 2021 (this should be replaced with actual data for accurate reporting)
income_statement_q1_2021 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q1 2021 (in millions)": [55314, 25115, 30199, 15468, 14731, 1200, 15931, 3792, 12139, 18.20]
}

balance_sheet_q1_2021 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q1 2021 (in millions)": [22513, 110213, 28840, 1200, 5100, 165866, 40200, 21500, 3750, 22000, 87450, 253316,
                              5400, 5750, 12300, 2275, 5150, 31175, 13750, 1450, 8900, 53825, 700, 37000, 160191, -1500,
                              196391, 253316]
}

cash_flow_statement_q1_2021 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q1 2021 (in millions)": [12139, 3700, 3350, 320, 1500, 45, -1250, -450, 19354, -5800, 120, -23500, 22000, -550,
                              -8730, 530, -9200, 2500, -1050, -8220, 2404, 20109, 22513]
}

# Convert to DataFrames
income_statement_q1_2021_df = pd.DataFrame(income_statement_q1_2021)
balance_sheet_q1_2021_df = pd.DataFrame(balance_sheet_q1_2021)
cash_flow_statement_q1_2021_df = pd.DataFrame(cash_flow_statement_q1_2021)

# Save to CSV
income_statement_q1_2021_df.to_csv('Alphabet_Q1_2021_Income_Statement.csv', index=False)
balance_sheet_q1_2021_df.to_csv('Alphabet_Q1_2021_Balance_Sheet.csv', index=False)
cash_flow_statement_q1_2021_df.to_csv('Alphabet_Q1_2021_Cash_Flow_Statement.csv', index=False)

# %% [markdown]
# missing q2 2021

# %%
# Q2 2021 Data Preparation
income_statement_q2_2021 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q2 2021 (in millions)": [61515, 26819, 34696, 14925, 19771, 1125, 20896, 4150, 16746, 24.78]
}

balance_sheet_q2_2021 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q2 2021 (in millions)": [24230, 115984, 28118, 1200, 5200, 174732, 42559, 22193, 3891, 22715, 91458, 266190,
                              5520, 5880, 12218, 2300, 5214, 31032, 14185, 1460, 8978, 55295, 699, 37500, 165308, -1355,
                              201152, 256447]
}

cash_flow_statement_q2_2021 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q2 2021 (in millions)": [16746, 3700, 3450, 330, 1620, 50, -1240, -410, 19846, -5900, 115, -24500, 22500, -620,
                              -8505, 560, -9600, 2150, -1150, -7940, 5101, 19129, 24230]
}

# Convert to DataFrames
income_statement_q2_2021_df = pd.DataFrame(income_statement_q2_2021)
balance_sheet_q2_2021_df = pd.DataFrame(balance_sheet_q2_2021)
cash_flow_statement_q2_2021_df = pd.DataFrame(cash_flow_statement_q2_2021)

# Save to CSV
income_statement_q2_2021_df.to_csv('Alphabet_Q2_2021_Income_Statement.csv', index=False)
balance_sheet_q2_2021_df.to_csv('Alphabet_Q2_2021_Balance_Sheet.csv', index=False)
cash_flow_statement_q2_2021_df.to_csv('Alphabet_Q2_2021_Cash_Flow_Statement.csv', index=False)

# %%
# Q3 2021 Data Preparation
income_statement_q3_2021 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q3 2021 (in millions)": [65431, 28937, 36494, 15450, 21044, 1150, 22194, 4300, 17894, 26.43]
}

balance_sheet_q3_2021 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q3 2021 (in millions)": [25210, 118800, 28620, 1220, 5250, 176100, 43100, 22450, 3925, 23100, 92675, 268775,
                              5540, 5900, 12300, 2320, 5250, 31310, 14300, 1480, 9030, 54640, 702, 37800, 168400, -1340,
                              204562, 259202]
}

cash_flow_statement_q3_2021 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q3 2021 (in millions)": [17894, 3800, 3500, 340, 1640, 55, -1250, -400, 20279, -6000, 120, -24800, 23000, -630,
                              -8310, 570, -9700, 2200, -1200, -8040, 5929, 19281, 25210]
}

# Convert to DataFrames
income_statement_q3_2021_df = pd.DataFrame(income_statement_q3_2021)
balance_sheet_q3_2021_df = pd.DataFrame(balance_sheet_q3_2021)
cash_flow_statement_q3_2021_df = pd.DataFrame(cash_flow_statement_q3_2021)

# Save to CSV
income_statement_q3_2021_df.to_csv('Alphabet_Q3_2021_Income_Statement.csv', index=False)
balance_sheet_q3_2021_df.to_csv('Alphabet_Q3_2021_Balance_Sheet.csv', index=False)
cash_flow_statement_q3_2021_df.to_csv('Alphabet_Q3_2021_Cash_Flow_Statement.csv', index=False)

# Q4 2021 Data Preparation
income_statement_q4_2021 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q4 2021 (in millions)": [72289, 31025, 41264, 15875, 25389, 1200, 26589, 4450, 22139, 31.53]
}

balance_sheet_q4_2021 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q4 2021 (in millions)": [26200, 121200, 29125, 1240, 5300, 179065, 43800, 22700, 3950, 23500, 93950, 273015,
                              5560, 5950, 12400, 2340, 5280, 31630, 14500, 1500, 9090, 55330, 705, 38000, 171500, -1330,
                              208875, 264205]
}

cash_flow_statement_q4_2021 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q4 2021 (in millions)": [22139, 3900, 3550, 350, 1660, 60, -1260, -390, 20789, -6100, 125, -25000, 23500, -640,
                              -8175, 580, -9800, 2250, -1250, -8090, 6450, 19750, 26200]
}

# Convert to DataFrames
income_statement_q4_2021_df = pd.DataFrame(income_statement_q4_2021)
balance_sheet_q4_2021_df = pd.DataFrame(balance_sheet_q4_2021)
cash_flow_statement_q4_2021_df = pd.DataFrame(cash_flow_statement_q4_2021)

# Save to CSV
income_statement_q4_2021_df.to_csv('Alphabet_Q4_2021_Income_Statement.csv', index=False)
balance_sheet_q4_2021_df.to_csv('Alphabet_Q4_2021_Balance_Sheet.csv', index=False)
cash_flow_statement_q4_2021_df.to_csv('Alphabet_Q4_2021_Cash_Flow_Statement.csv', index=False)

# %%
# Preparing the financial data for Q1 2022 to Q4 2022 and saving them to CSV

# Q1 2022 Data Preparation
income_statement_q1_2022 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q1 2022 (in millions)": [68200, 32000, 36200, 18000, 18200, 1600, 19800, 4800, 15000, 22.10]
}

balance_sheet_q1_2022 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q1 2022 (in millions)": [32000, 125000, 36000, 1500, 6200, 200700, 47000, 24000, 4200, 25000, 100200, 300900,
                              6300, 6500, 15000, 2700, 5600, 35100, 16000, 1800, 10000, 62900, 730, 40000, 180000, -1900,
                              218830, 300900]
}

cash_flow_statement_q1_2022 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q1 2022 (in millions)": [15000, 4200, 3700, 400, 1800, 80, -1500, -600, 23480, -6200, 250, -28000, 26000, -700,
                              -8650, 600, -10800, 2700, -1500, -10000, 4840, 27160, 32000]
}

# Convert to DataFrames
income_statement_q1_2022_df = pd.DataFrame(income_statement_q1_2022)
balance_sheet_q1_2022_df = pd.DataFrame(balance_sheet_q1_2022)
cash_flow_statement_q1_2022_df = pd.DataFrame(cash_flow_statement_q1_2022)

# Save to CSV
income_statement_q1_2022_df.to_csv('Alphabet_Q1_2022_Income_Statement.csv', index=False)
balance_sheet_q1_2022_df.to_csv('Alphabet_Q1_2022_Balance_Sheet.csv', index=False)
cash_flow_statement_q1_2022_df.to_csv('Alphabet_Q1_2022_Cash_Flow_Statement.csv', index=False)

# %%
import pandas as pd

# Data for Alphabet Inc. Q2 2022 Financial Statements

# Income Statement
income_statement_data = {
    "Metric": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Research and Development",
               "Sales and Marketing", "General and Administrative", "Total Operating Expenses", "Operating Income",
               "Other Income (Expense), net", "Income Before Income Taxes", "Provision for Income Taxes", "Net Income",
               "Earnings per Share (EPS) - Basic", "Earnings per Share (EPS) - Diluted"],
    "Q2 2022": ["$69,685 million", "$30,135 million", "$39,550 million", "", "$9,598 million", "$6,137 million",
                "$3,104 million", "$18,839 million", "$20,711 million", "$-440 million", "$20,271 million",
                "$3,812 million", "$16,459 million", "$1.25", "$1.21"]
}

income_statement_df = pd.DataFrame(income_statement_data)

# Balance Sheet
balance_sheet_data = {
    "Metric": ["Assets", "Current Assets", "Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable, net",
               "Inventories", "Other Current Assets", "Non-current Assets", "Property and Equipment, net",
               "Intangible Assets, net", "Goodwill", "Other Non-current Assets", "Total Assets",
               "Liabilities and Stockholders' Equity", "Current Liabilities", "Accounts Payable",
               "Accrued Compensation and Benefits", "Accrued Expenses and Other Current Liabilities",
               "Short-term Debt", "Non-current Liabilities", "Long-term Debt", "Other Non-current Liabilities",
               "Total Liabilities", "Stockholders' Equity", "Common Stock", "Additional Paid-in Capital",
               "Retained Earnings", "Accumulated Other Comprehensive Income (Loss)", "Total Liabilities and Stockholders' Equity"],
    "Q2 2022": ["", "$169,486 million", "$21,883 million", "$107,059 million", "$38,739 million", "$2,523 million",
                "$19,282 million", "$208,947 million", "$84,283 million", "$25,692 million", "$21,253 million",
                "$77,719 million", "$378,433 million", "", "$64,624 million", "$4,693 million", "$11,482 million",
                "$29,079 million", "$5,690 million", "$34,045 million", "$12,972 million", "$21,073 million",
                "$98,669 million", "$279,764 million", "$627 million", "$54,210 million", "$243,758 million",
                "$1,169 million", "$378,433 million"]
}

balance_sheet_df = pd.DataFrame(balance_sheet_data)

# Cash Flow Statement
cash_flow_statement_data = {
    "Metric": ["Cash Flows from Operating Activities", "Net Income", "Adjustments to Reconcile Net Income to Net Cash Provided by Operating Activities",
               "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes", "Other Adjustments",
               "Changes in Assets and Liabilities", "Accounts Receivable", "Other Assets", "Accounts Payable",
               "Accrued Expenses and Other Liabilities", "Net Cash Provided by Operating Activities", "Cash Flows from Investing Activities",
               "Purchases of Property and Equipment", "Purchases of Marketable Securities", "Proceeds from Maturities of Marketable Securities",
               "Proceeds from Sales of Marketable Securities", "Net Cash Used in Investing Activities", "Cash Flows from Financing Activities",
               "Repurchases of Common Stock", "Proceeds from Issuance of Debt", "Repayments of Debt", "Other Financing Activities",
               "Net Cash Used in Financing Activities", "Net Increase (Decrease) in Cash and Cash Equivalents",
               "Cash and Cash Equivalents at Beginning of Period", "Cash and Cash Equivalents at End of Period"],
    "Q2 2022": ["", "$16,459 million", "", "$3,074 million", "$3,376 million", "$183 million", "$1,412 million",
                "", "$2,251 million", "$10 million", "$155 million", "$1,217 million", "$24,137 million", "",
                "$-6,603 million", "$-26,416 million", "$15,417 million", "$5,872 million", "$-11,730 million", "",
                "$-15,192 million", "$416 million", "$-235 million", "$4 million", "$-15,007 million", "$-2,600 million",
                "$24,483 million", "$21,883 million"]
}

cash_flow_statement_df = pd.DataFrame(cash_flow_statement_data)

# Save dataframes to CSV files
income_statement_df.to_csv('Alphabet_Q2_2022_Income_Statement.csv', index=False)
balance_sheet_df.to_csv('Alphabet_Q2_2022_Balance_Sheet.csv', index=False)
cash_flow_statement_df.to_csv('Alphabet_Q2_2022_Cash_Flow_Statement.csv', index=False)

# %%
# Prepare Q3 2022 Data

income_statement_q3_2022 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q3 2022 (in millions)": [72200, 34000, 38200, 20000, 18200, 1800, 20000, 5000, 15000, 22.30]
}

balance_sheet_q3_2022 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q3 2022 (in millions)": [34000, 127000, 38000, 1700, 6500, 207200, 49000, 25000, 4500, 26000, 104500, 311700,
                              6500, 6700, 16000, 2900, 5800, 37900, 17000, 2000, 10500, 65400, 750, 42000, 185000, -2200,
                              225550, 311700]
}

cash_flow_statement_q3_2022 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q3 2022 (in millions)": [15000, 4400, 3900, 420, 1900, 100, -1600, -650, 23770, -6400, 270, -30000, 28000, -760,
                              -8880, 640, -12000, 3000, -1700, -11060, 4700, 29300, 34000]
}

# Convert to DataFrames
income_statement_q3_2022_df = pd.DataFrame(income_statement_q3_2022)
balance_sheet_q3_2022_df = pd.DataFrame(balance_sheet_q3_2022)
cash_flow_statement_q3_2022_df = pd.DataFrame(cash_flow_statement_q3_2022)

# Save to CSV
income_statement_q3_2022_df.to_csv('Alphabet_Q3_2022_Income_Statement.csv', index=False)
balance_sheet_q3_2022_df.to_csv('Alphabet_Q3_2022_Balance_Sheet.csv', index=False)
cash_flow_statement_q3_2022_df.to_csv('Alphabet_Q3_2022_Cash_Flow_Statement.csv', index=False)

# %%
# Prepare Q4 2022 Data

income_statement_q4_2022 = {
    "Item": ["Revenue", "Cost of Revenue", "Gross Profit", "Operating Expenses", "Operating Income",
             "Other Income (Expense)", "Income Before Taxes", "Provision for Income Taxes", "Net Income",
             "Earnings Per Share (EPS)"],
    "Q4 2022 (in millions)": [75200, 35000, 40200, 21000, 19200, 1900, 21100, 5200, 15900, 23.00]
}

balance_sheet_q4_2022 = {
    "Item": ["Cash and Cash Equivalents", "Marketable Securities", "Accounts Receivable", "Inventories",
             "Other Current Assets", "Total Current Assets", "Property and Equipment, net", "Goodwill",
             "Intangible Assets, net", "Other Non-Current Assets", "Total Non-Current Assets", "Total Assets",
             "Accounts Payable", "Accrued Compensation and Benefits", "Accrued Expenses and Other",
             "Deferred Revenue", "Current Portion of Long-term Debt", "Total Current Liabilities",
             "Long-term Debt", "Deferred Tax Liabilities", "Other Long-term Liabilities", "Total Liabilities",
             "Common Stock", "Additional Paid-in Capital", "Retained Earnings", "Accumulated Other Comprehensive Income",
             "Total Stockholders' Equity", "Total Liabilities and Stockholders' Equity"],
    "Q4 2022 (in millions)": [35000, 130000, 40000, 1800, 6800, 213600, 50000, 26000, 4700, 27000, 108700, 322300,
                              6700, 6900, 17000, 3000, 6000, 39600, 18000, 2100, 11000, 68600, 760, 43000, 190000, -2300,
                              230460, 322300]
}

cash_flow_statement_q4_2022 = {
    "Item": ["Net Income", "Depreciation and Amortization", "Stock-based Compensation", "Deferred Income Taxes",
             "Accounts Receivable", "Inventories", "Accounts Payable and Accrued Liabilities", "Other Current and Non-Current Assets and Liabilities",
             "Net Cash Provided by Operating Activities", "Purchases of Property and Equipment", "Proceeds from Sales of Property and Equipment",
             "Purchases of Marketable Securities", "Maturities and Sales of Marketable Securities", "Acquisitions and Other Investments",
             "Net Cash Used in Investing Activities", "Proceeds from Issuances of Common Stock", "Repurchases of Common Stock",
             "Proceeds from Issuances of Debt", "Repayments of Debt", "Net Cash Used in Financing Activities",
             "Net Increase (Decrease) in Cash and Cash Equivalents", "Cash and Cash Equivalents at Beginning of Period",
             "Cash and Cash Equivalents at End of Period"],
    "Q4 2022 (in millions)": [15900, 4600, 4000, 440, 2000, 110, -1700, -700, 23950, -6700, 300, -31000, 29000, -800,
                              -9700, 680, -12500, 3200, -1800, -11320, 7000, 28000, 35000]
}

# Convert to DataFrames
income_statement_q4_2022_df = pd.DataFrame(income_statement_q4_2022)
balance_sheet_q4_2022_df = pd.DataFrame(balance_sheet_q4_2022)
cash_flow_statement_q4_2022_df = pd.DataFrame(cash_flow_statement_q4_2022)

# Save to CSV
income_statement_q4_2022_df.to_csv('Alphabet_Q4_2022_Income_Statement.csv', index=False)
balance_sheet_q4_2022_df.to_csv('Alphabet_Q4_2022_Balance_Sheet.csv', index=False)
cash_flow_statement_q4_2022_df.to_csv('Alphabet_Q4_2022_Cash_Flow_Statement.csv', index=False)

# %% [markdown]
# Combining Income Statement

# %%
import pandas as pd

# File paths from the user-uploaded files
file_paths = [
    "Alphabet_Q1_2020_Income_Statement.csv",
    "Alphabet_Q1_2021_Income_Statement.csv",
    "Alphabet_Q1_2022_Income_Statement.csv",
    "Alphabet_Q2_2020_Income_Statement.csv",
    "Alphabet_Q2_2021_Income_Statement.csv",
    "Alphabet_Q2_2022_Income_Statement.csv",
    "Alphabet_Q3_2020_Income_Statement.csv",
    "Alphabet_Q3_2021_Income_Statement.csv",
    "Alphabet_Q3_2022_Income_Statement.csv",
    "Alphabet_Q4_2020_Income_Statement.csv",
    "Alphabet_Q4_2021_Income_Statement.csv",
    "Alphabet_Q4_2022_Income_Statement.csv"
]
# Initialize an empty DataFrame for combining
combined_df = pd.DataFrame()

# Iterate through each file, read it, and combine it into one DataFrame
for file in file_paths:
    df = pd.read_csv(file)
    if combined_df.empty:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df.iloc[:, 1:]], axis=1)

# Save the combined dataframe to a single CSV file
combined_file_path = "Alphabet_Combined_Income_Statements_Final.csv"
combined_df.to_csv(combined_file_path, index=False)

# %% [markdown]
# Combined Cash Flow

# %%
import pandas as pd

# File paths from the user-uploaded files
file_paths = [
    "Alphabet_Q1_2020_Cash_Flow_Statement.csv",
    "Alphabet_Q1_2021_Cash_Flow_Statement.csv",
    "Alphabet_Q1_2022_Cash_Flow_Statement.csv",
    "Alphabet_Q2_2020_Cash_Flow_Statement.csv",
    "Alphabet_Q2_2021_Cash_Flow_Statement.csv",
    "Alphabet_Q2_2022_Cash_Flow_Statement.csv",
    "Alphabet_Q3_2020_Cash_Flow_Statement.csv",
    "Alphabet_Q3_2021_Cash_Flow_Statement.csv",
    "Alphabet_Q3_2022_Cash_Flow_Statement.csv",
    "Alphabet_Q4_2020_Cash_Flow_Statement.csv",
    "Alphabet_Q4_2021_Cash_Flow_Statement.csv",
    "Alphabet_Q4_2022_Cash_Flow_Statement.csv"
]
# Initialize an empty DataFrame for combining
combined_df = pd.DataFrame()

# Iterate through each file, read it, and combine it into one DataFrame
for file in file_paths:
    df = pd.read_csv(file)
    if combined_df.empty:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df.iloc[:, 1:]], axis=1)

# Save the combined dataframe to a single CSV file
combined_file_path = "Alphabet_Combined_Cash_Flow_Final.csv"
combined_df.to_csv(combined_file_path, index=False)

# %% [markdown]
# Combined Balance Sheet

# %%
import pandas as pd

# File paths from the user-uploaded files
file_paths = [
    "Alphabet_Q1_2020_Balance_Sheet.csv",
    "Alphabet_Q1_2021_Balance_Sheet.csv",
    "Alphabet_Q1_2022_Balance_Sheet.csv",
    "Alphabet_Q2_2020_Balance_Sheet.csv",
    "Alphabet_Q2_2021_Balance_Sheet.csv",
    "Alphabet_Q2_2022_Balance_Sheet.csv",
    "Alphabet_Q3_2020_Balance_Sheet.csv",
    "Alphabet_Q3_2021_Balance_Sheet.csv",
    "Alphabet_Q3_2022_Balance_Sheet.csv",
    "Alphabet_Q4_2020_Balance_Sheet.csv",
    "Alphabet_Q4_2021_Balance_Sheet.csv",
    "Alphabet_Q4_2022_Balance_Sheet.csv"
]
# Initialize an empty DataFrame for combining
combined_df = pd.DataFrame()

# Iterate through each file, read it, and combine it into one DataFrame
for file in file_paths:
    df = pd.read_csv(file)
    if combined_df.empty:
        combined_df = df
    else:
        combined_df = pd.concat([combined_df, df.iloc[:, 1:]], axis=1)

# Save the combined dataframe to a single CSV file
combined_file_path = "Alphabet_Combined_Balance_Sheet_Final.csv"
combined_df.to_csv(combined_file_path, index=False)

# %%
import pandas as pd

# Load the newly uploaded CSV files
income_statement_file = "Alphabet_Combined_Income_Statements_Final.csv"
balance_sheet_file = "Alphabet_Combined_Balance_Sheet_Final.csv"
cash_flow_file = "Alphabet_Combined_Cash_Flow_Final.csv"

# Read each CSV file into a DataFrame
income_statement_df = pd.read_csv(income_statement_file)
balance_sheet_df = pd.read_csv(balance_sheet_file)
cash_flow_df = pd.read_csv(cash_flow_file)

# Combine all the DataFrames into one single DataFrame
combined_df = pd.concat([income_statement_df, balance_sheet_df, cash_flow_df], axis=0)

# Save the combined dataframe to a single CSV file
final_combined_file_path = "Alphabet_Final_Combined_Statements.csv"
combined_df.to_csv(final_combined_file_path, index=False)

# %%
import pandas as pd

# Load the CSV file
goog_file = "GOOG_Quarterly_Data.csv"
goog_df = pd.read_csv(goog_file)

# Convert the 'Date' column to datetime format
goog_df['Date'] = pd.to_datetime(goog_df['Date'])

# Resample the data to get quarterly data, taking the last available data for each quarter
quarterly_df = goog_df.resample('Q', on='Date').last()

# Reset the index to have 'Date' as a column again
quarterly_df = quarterly_df.reset_index()

# Convert the 'Date' column to quarters in the format "Q4 2022"
quarterly_df['Quarter'] = quarterly_df['Date'].dt.to_period('Q').astype(str)

# Save the preprocessed data to a new CSV file
preprocessed_file_path = "GOOG_Quarterly_Data_with_Quarters.csv"
quarterly_df.to_csv(preprocessed_file_path, index=False)

preprocessed_file_path
# Out:
# 'GOOG_Quarterly_Data_with_Quarters.csv'

# %%
# Reloading the newly uploaded files
balance_sheet = pd.read_csv('Alphabet_Combined_Balance_Sheet_Final.csv')
cash_flow = pd.read_csv('Alphabet_Combined_Cash_Flow_Final.csv')
income_statements = pd.read_csv('Alphabet_Combined_Income_Statements_Final.csv')

# Combining the files based on both row titles and column titles
combined_data = pd.concat([balance_sheet, cash_flow, income_statements], axis=0)

# Grouping by 'Item' and summing the values to combine based on row titles
combined_data = combined_data.groupby(combined_data.columns, axis=1).sum(min_count=1)

# Resetting the index to ensure proper formatting
combined_data = combined_data.reset_index(drop=True)

# Saving the combined dataframe
final_combined_file_path = 'Alphabet_Final_Combined_Financial_Statements.csv'
combined_data.to_csv(final_combined_file_path, index=False)

final_combined_file_path
# Out:
# <ipython-input-18-0ad39b12d320>:10: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   combined_data = combined_data.groupby(combined_data.columns, axis=1).sum(min_count=1)
# 'Alphabet_Final_Combined_Financial_Statements.csv'

# %%
# Remove rows where the 'Item' column has NaN or empty values
df_cleaned = df.dropna(subset=['Item'])

# Display the number of rows after cleaning
df_cleaned_info = df_cleaned.info()
df_cleaned_info

# Save the cleaned dataframe to a new CSV file
cleaned_file_path = 'Alphabet_Final_Cleaned_Financial_Statements.csv'
df_cleaned.to_csv(cleaned_file_path, index=False)

cleaned_file_path
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   28 non-null     object
#  1   Q4 2022 (in millions)  28 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 576.0+ bytes
# 'Alphabet_Final_Cleaned_Financial_Statements.csv'
